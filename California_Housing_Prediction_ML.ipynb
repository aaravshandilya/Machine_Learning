# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pip install numpy pandas matplotlib scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 80.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 85.0 MB/s eta 0:00:00:00:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
{sys.executable} -m pip install numpy pandas matplotlib scikit-learn seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
from sklearn.datasets import fetch_california_housing

# %%
housing = fetch_california_housing(as_frame=True)

# %%
df = housing.frame

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB
# None

# %% [markdown]
# # Printing Dataset

# %%
print(df.describe())
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))

# %% [markdown]
# # This will create a Heatmap for the housing chart

# %%
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# # 1) Using LinReg

# %%
plt.show()

# %%
X = df.drop("MedHouseVal", axis=1)

# %%
y = df["MedHouseVal"]

# %%
from sklearn.model_selection import train_test_split #importing the ratio of how much data we are training and how much we are splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,Y,test_size=0.1, random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(
#       2     X,Y,test_size=0.1, random_state=42
#       3 )
#
# NameError: name 'train_test_split' is not defined

# %%
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse_lin = mean_squared_error(y_test, y_pred)
r2_lin = r2_score(y_test, y_pred)

print("Linear Regression MSE:", mse_lin)
print("Linear Regression R²:", r2_lin)
# Out:
# Linear Regression MSE: 0.5558915986952444
# Linear Regression R²: 0.5757877060324508

# %% [markdown]
# # Chart for accuracy of model using Linear Regression

# %%
plt.scatter(y_test, y_pred, alpha=0.3)
plt.xlabel("Actual House Value")
plt.ylabel("Predicted House Value")
plt.title("Actual vs Predicted Prices")
plt.show()

# %% [markdown]
# # 2) Using Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=200, random_state=42, n_jobs=-1)

# %% [markdown]
# rf.fit(X_train, y_train)

# %%
y_pred_rf = rf.predict(X_test)

# %%
mse_rf = mean_squared_error(y_test, y_pred_rf)

# %%
r2_rf = r2_score(y_test, y_pred_rf)

# %%
print("Random Forest R²:", r2_rf)
print("Random Forest MSE:", mse_rf)
# Out:
# Random Forest R²: 0.8061857564039718
# Random Forest MSE: 0.2539759249192042

# %% [markdown]
# # Chart of accuracy of the Model when using Random Forest

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred_rf, alpha=0.3, color='green')
plt.xlabel("Actual House Value")
plt.ylabel("Predicted House Value")
plt.title("Random Forest: Actual vs Predicted")
plt.show()

# %%
comparison = pd.DataFrame({
    "Model": ["Linear Regression", "Random Forest"],
    "MSE": [mse_lin, mse_rf],
    "R²": [r2_lin, r2_rf]
})

comparison
# Out:
#                Model       MSE        R²
# 0  Linear Regression  0.555892  0.575788
# 1      Random Forest  0.253976  0.806186

# %%
plt.figure(figsize=(8,6))

# Linear Regression
plt.scatter(y_test, y_pred, alpha=0.5, c='red', label='Linear Regression')

# Random Forest
plt.scatter(y_test, y_pred_rf, alpha=0.5, c='blue', label='Random Forest')

# Plot a diagonal line (perfect prediction)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)

plt.xlabel("Actual House Value")
plt.ylabel("Predicted House Value")
plt.title("Model Predictions Comparison")
plt.legend()
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8,6))

sns.kdeplot(x=y_test, y=y_pred, cmap="Reds", fill=True, alpha=0.5, label='Linear Regression')
sns.kdeplot(x=y_test, y=y_pred_rf, cmap="Blues", fill=True, alpha=0.5, label='Random Forest')

plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel("Actual House Value")
plt.ylabel("Predicted House Value")
plt.title("Prediction Density Comparison")
plt.show()

# %%
pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 64.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
{sys.executable} -m pip install numpy pandas matplotlib seaborn scikit-learn plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import plotly.express as px
import pandas as pd

# Create a DataFrame for plotting
df_3d = pd.DataFrame({
    "Actual": y_test,
    "Model1_Pred": y_pred,       # Linear Regression
    "Model2_Pred": y_pred_rf     # Random Forest
})

# Plot 3D scatter
fig = px.scatter_3d(
    df_3d,
    x="Actual",
    y="Model1_Pred",
    z="Model2_Pred",
    color="Actual",                     # Heatmap coloring
    color_continuous_scale="Viridis",
    opacity=0.7,
    size_max=5,
    title="3D Comparison of Model Predictions"
)

fig.update_layout(
    scene=dict(
        xaxis_title='Actual House Value',
        yaxis_title='Linear Regression Prediction',
        zaxis_title='Random Forest Prediction'
    )
)

fig.show()
